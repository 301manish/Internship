# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# 1. Write a python program to display IMDB’s Top rated 100 Indian movies’ data
# https://www.imdb.com/list/ls056092300/ (i.e. name, rating, year ofrelease) and make data frame.

# %%
request=requests.get("https://www.imdb.com/list/ls056092300/")
request
# Out:
# <Response [403]>

# %%
#Server code error

# %%
soup=BeautifulSoup(request.content)
soup
# Out:
# <html>
# <head><title>403 Forbidden</title></head>
# <body>
# <center><h1>403 Forbidden</h1></center>
# </body>
# </html>

# %%
#name of movie

# %%
movie_name=soup.find_all("div",class_="list-page-mc-list-content")

# %%
#creating a list

# %%
names=[]

# %%
for i in soup.find_all("h3",class_="ipc-title__text"):
    names.append(i.text)
    
names
# Out:
# []

# %%
# result not getting

# %%
ratings=[]

# %%
for i in soup.find_all("span",class_="ipc-rating-star--rate"):
    ratings.append(i.text)
ratings
# Out:
# []

# %%
#result not getting

# %%
years=[]

# %%
for i in soup.find_all("spam",class_="sc-b189961a-8 kLaxqf dli-title-metadata-item"):
    years.append(i.text)
years
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 for i in soup.find_all("spam",class_="sc-b189961a-8 kLaxqf dli-title-metadata-item"):
#       2     years.append(i.text)
# ----> 3 years
#
# NameError: name 'years' is not defined

# %%
#making data frame

# %%
import pandas as pd
df=pd.DataFrame({"Name":names,"Rating":ratings,"Year":years})
df
# Out:
# Empty DataFrame
# Columns: [Name, Rating, Year]
# Index: []

# %%
#result not getting pls assist.

# %% [markdown]
# 2) Write a python program to scrape details of all the posts from https://www.patreon.com/coreyms .Scrape the
# heading, date, content and the likes for the video from the link for the youtube video from the post.

# %%
request=requests.get("https://www.patreon.com/coreyms")
request
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(request.content)
soup
# Out:
# <!DOCTYPE html>
# <html><head><meta charset="utf-8"/><script type="text/javascript">
#             window.patreonConfig = {"apiServer":"www.patreon.com/api","nionDisableDefaultIncludes":true,"formattingLocale":"en-US","eventLoggingPlatform":"Web","isWebView":false,"pathname":"/\u003cstring:campaign_identifier\u003e","is_impersonating":false,"csrfSignature":"Da37G75pv5JkM25ZeLpMJHyUiIFWmNlk3F0v7-i2_g8"};
# ...

# %%
heading=soup.find_all("div",class_="sc-bYoBSM eOvyxw")
heading
# Out:
# []

# %%
#result not getting.....where i am commiting mistake?

# %% [markdown]
# 3) Write a python program to scrape house details from mentioned URL. It should include house title, location,
# area, EMI and price from https://www.nobroker.in/ .Enter three localities which are Indira Nagar, Jayanagar,
# Rajaji Nagar.

# %%
request=requests.get("https://www.nobroker.in/")
request
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(request.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch preconnect"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch preconnect"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="https://assets.adobedtm.com" rel="dns-prefetch preconnect"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <link href="https://hs.nobroker.in" rel="dns-prefetch preconnect"/>
# <!--<meta charset="utf-8"/>-->
# <meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# ...

# %%
listings = soup.find_all('div', class_='listing-item')

# %%
for listing in listings:
            title = listing.find('span', class_='listing-title').text.strip()
            location = listing.find('div', class_='listing-location').text.strip()
            area = listing.find('div', class_='listing-area').text.strip()
            emi = listing.find('div', class_='listing-emi').text.strip()
            price = listing.find('div', class_='listing-price').text.strip()

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# 4) Write a python program to scrape first 10 product details which include product name , price , Image URL from
# https://www.bewakoof.com/bestseller?sort=popular

# %%
url_site="https://www.bewakoof.com/bestseller?sort=popular"

request=requests.get("https://www.bewakoof.com/bestseller?sort=popular")
request
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(request.content)
soup
# Out:
# <!DOCTYPE html>
# <html><head>
# <meta content="4d8KRpUCzf-ghquF_HLNphibw_xRvUS3kAvzpnF2KlA" name="google-site-verification"/>
# <meta content="-TTsyPFCOB4bQlMHawiO4oZGcGX9pxqenB_NZNhhhgA" name="google-site-verification"/>
# <meta content="wQa0CQvt7fd2VIoa9qhkevhvwuBvhRwiaB3hVizI9OY" name="google-site-verification"/>
# <meta content="o7KS3-fVt15m4Cc1HeYh5HIpv532A4FvvYQzIf-LnsQ" name="google-site-verification"/>
# <link href="https://images.bewakoof.com" rel="preconnect"/>
# <link href="https://images.bewakoof.com" rel="dns-prefetch"/>
# <link href="https://static.bewakoof.com" rel="preconnect"/>
# <link href="https://static.bewakoof.com" rel="dns-prefetch"/>
# <link href="https://cdn.polyfill.io" rel="preconnect"/>
# <link href="https://cdn.polyfill.io" rel="dns-prefetch"/>
# <link href="https//www.googletagmanager.com" rel="preconnect"/>
# <link href="https//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
product=[]

# %%
for i in soup.find_all("div",class_="prodCardContainer"):
    product.append(i.text)
product
# Out:
# ["0OVERSIZED FITbewakoof x dcMen's Red The Batman Graphic Printed Oversized T-shirt₹599₹1299₹549For TriBe Members100% COTTONFew Left4.4Bewakoof®Women's Purple Music Is My Escape Graphic Printed T-shirt₹649₹1249₹599For TriBe Members100% COTTONOVERSIZED FIT4.3Bewakoof®Men's Red Moon Rider Graphic Printed Oversized T-shirt₹699₹1149₹639For TriBe Members100% COTTONOVERSIZED FITBewakoof®Men's Purple Beast Within Graphic Printed Oversized T-shirt₹699₹1499₹639For TriBe Members100% COTTONOVERSIZED FIT4.4bewakoof x marvelMen's Blue Moon Knight Graphic Printed Oversized T-shirt₹499₹1299₹459For TriBe Members100% COTTONOVERSIZED FITBewakoof®Men's Blue Peace Not War Graphic Printed Oversized T-shirt₹709₹1049₹649For TriBe Members100% COTTONOVERSIZED FITbewakoof x dcMen's White Vengeance Typography Oversized T-shirt₹599₹1299₹549For TriBe Members100% COTTONOVERSIZED FIT4.3Bewakoof®Men's Black Warriors Graphic Printed Oversized T-shirt₹629₹1299₹579For TriBe Members100% COTTONBOYFRIEND FIT4.5Bewakoof®W
# ...

# %%
price=[]

# %%
for i in soup.find_all("span",class_="sellingFastBox"):
    price.append(i.text)
price
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  <span class="sellingFastBox"></span>,
#  <span class="sellingFastBox"></span>,
#  <span class="sellingFastBox"></span>,
#  <span class="sellingFastBox"></span>,
#  <span class="sellingFastBox"></span>,
#  <span class="sellingFastBox"></span>,
#  <span class="sellingFastBox"></span>,
#  <span class="sellingFastBox"></span>,
#  <span class="sellingFastBox"></span>,
#  <span class="sellingFastBox"></span>,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '₹',
#  '',
#  '1299',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
image=[]

# %%
for i in soup.find_all("img",scr="https://images.bewakoof.com/t640/men-s-red-the-batman-graphic-printed-oversized-t-shirt-480316-1715257617-1.jpg"):
    image.append(i["data-src"])
image
# Out:
# []

# %% [markdown]
# making dataframe

# %%
import pandas as pd
df=pd.DataFrame({"product":product,"price":price,"image":image})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 import pandas as pd
# ----> 2 df=pd.DataFrame({"product":product,"price":price,"image":image})
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...

# %%
#Result not getting, pls assist where i am commiting mistake
